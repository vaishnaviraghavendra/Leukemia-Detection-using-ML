# %% [markdown]
# # **IMPORT LIBRARIES **

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %% [markdown]
# #**Training Data Augmentation**

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/content_leukimia/train',
target_size = (64, 64),
batch_size = 32,
class_mode = 'binary')
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/content_leukimia/train',
target_size = (64, 64),
batch_size = 32,
class_mode = 'binary')

# %% [markdown]
# #**CREATING NEURAL MODEL **

# %%
classifier = Sequential()
# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))
# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
# Step 3 - Flattening
classifier.add(Flatten())
# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))
# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # **START TRAINING **

# %%
classifier.fit_generator(training_set,
steps_per_epoch = 4,
epochs = 100,
validation_data = test_set,
validation_steps = 4)

# %% [markdown]
# # **DIAGNOSIS OF LEUKEMIA **

# %%
import cv2                                    #import cv2 library to display umage 
from google.colab.patches import cv2_imshow
path = "/content/drive/MyDrive/content_leukimia/train/hem/UID_H11_10_1_hem.bmp" # enter path of image 
Image= cv2.imread(path)         #read image and store in Image variable
cv2_imshow(Image)               #display image 
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/content_leukimia/train/hem/UID_H11_10_1_hem.bmp', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)
print(result)
# training_set.class_indices
if result[0][0] == 1:
  prediction = 'LEUKEMIA +VE'
  print('image1_prediction=')
  print(prediction)
else:
  prediction = 'LEUKEMIA -VE'# Importing the Keras libraries and packagesset.class_indices
  print('image1_prediction=')
  print(prediction)

# %%
import cv2                                    #import cv2 library to display umage 
from google.colab.patches import cv2_imshow
path = "/content/drive/MyDrive/content_leukimia/train/all/UID_5_10_1_all.bmp" # enter path of image 
Image= cv2.imread(path)         #read image and store in Image variable
cv2_imshow(Image)               #display image 
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/content_leukimia/train/all/UID_5_10_1_all.bmp', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)
print(result)
# training_set.class_indices
if result[0][0] == 1:
  prediction = 'LEUKEMIA +VE'
  print('image1_prediction=')
  print(prediction)
else:
  prediction = 'LEUKEMIA -VE'# Importing the Keras libraries and packagesset.class_indices
  print('image1_prediction=')
  print(prediction)

# %%
  print(prediction)
else:
  prediction = 'LEUKEMIA -VE'# Importing the Keras libraries and packagesset.class_indices
  print('image1_prediction=')
  print(prediction)

# %%
import cv2                                    #import cv2 library to display umage 
from google.colab.patches import cv2_imshow
path = "/content/drive/MyDrive/content_leukimia/train/all/UID_5_17_1_all.bmp" # enter path of image 
Image= cv2.imread(path)         #read image and store in Image variable
cv2_imshow(Image)               #display image 
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/content_leukimia/train/all/UID_5_17_1_all.bmp', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)
print(result)
# training_set.class_indices
if result[0][0] == 0:
  prediction = 'LEUKEMIA +VE'
  print('image1_prediction=')
  print(prediction)
else:
  prediction = 'LEUKEMIA -VE'# Importing the Keras libraries and packagesset.class_indices
  print('image1_prediction=')
  print(prediction)
